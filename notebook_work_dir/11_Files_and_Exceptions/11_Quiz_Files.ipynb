# %% [markdown]
# # 1. Где хранятся файлы на компьютере?
# * Вторичная память
# * В машинном языке
# * На материнской лате
# * В оперативной памяти

# %% [markdown]
# # 2. Что хранится в описателе файла, возвращаемом в случае успешного выполнения вызова метода open()?
# * Описатель хранит список всех файлов в указанной директории на жестком диске
# * Описатель является соединением с данными в файле
# * Описатель содержит первые 10 строк из файла
# * Все данные из файла вычитываются в основную память и хранятся в описателе

# %% [markdown]
# # 3. Для чего используется второй параметр метода open()?
# * Содержит список директорий для поиска файла который нужно открыть
# * Содержит максимальный ожидаемый размер открываемого файла
# * Указывает на каком диске хранится файл
# * Указывает режим доступа к файлу: на запись или на чтение

# %% [markdown]
# # 4. Какую Python функцию вы можете использовать для запроса у пользователя имени открываемого файла?
# * read()
# * raw_input()
# * file_input()
# * cin

# %% [markdown]
# # 5. Каково предназначение символа новой строки в текстовом файле?
# * Позволяет получить даступ к данным в файле в случайном порядке
# * Создает новое сетевое соединение для получения данных по сети
# * Позволяет открыть более одного файла и и читать данные из них в синхронизированном порядке
# * Указывает на конец строки текста в файле и начала следующей

# %% [markdown]
# # 6. Если открыть файл следующим образом:
# <pre>
#     <code>xfile = open('mbox.txt')</code>
# Какое выражение может быть использовано для чтения фала построчно?
# * <code>for line in xfile:</code>
# * <code>while line = xfile.gets</code>
# * <code>while ((line = xfile.readLine()) != null {</code>
# * <code>while (<xfile>) {</code>
# <pre>

# %% [markdown]
# # 7. Что делает следующий код Python?
# <pre>
#     fhand = open('mbox.txt')
#     x = 0
#     for line in fhand:
#         x += 1
#     print x
# </pre>
# * Удаляет ведущие и завершающие пробелы из каждой строки файла mbox.txt
# * Конвертирует строки в файле mbox.txt в верхний регистр
# * Меняет порядок следования строк в файле mbox.txt
# * Считает количество строк в файле mbox.txt

# %% [markdown]
# # 8. Если вы написали Python программу для чтения текстового файла и вы увидели дополнительные пустые строки на выходе, которых не было в файле, как показано ниже, какой Python string метод позволит решить эту проблему?
# <pre>
#
# From: stephen.marquard@uct.ac.za
#
# From: louis@media.berkeley.edu
#
# From: zqian@umich.edu
#
# From: rjlowe@iupui.edu
#
# ...
# </pre>
# * strip()
# * ljust()
# * find()
#
# * startswith()

# %% [markdown]
# # 9. Следующий код кидает исключение, если пользователь вводит имя несуществующего файла. Как можно избежать возникновения исключения и вывести на печать сообщение об ошибке?
# <pre>
# fname = raw_input('Enter the file name: ')
# fhand = open(fname)
# </pre>
# * Использовать обработчики сигналов
# * setjmp / longjmp
# * try / except
# * begin / rescue / end

# %% [markdown]
# # 10. Что делает следующий код?
# <pre>
# fhand = open('mbox-short.txt')
# inp = fhand.read()
# </pre>
# * Конвертирует текстовый файл в графическое изображение
# * Запрашивает у пользователя имя файла
# * Проверяет существование файла и возможность записи в него
# * Вычитывает весь файл в переменную inp как строку
